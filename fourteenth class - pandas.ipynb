# %%
b = open ('data.csv','x')
b.close()

# %%
b = open('data.csv','r')
print(b.read())
b.close()
# Out:
# Name,Age,Address
# Aayush,23,Kathmandu
# Shyam,25,Patan

# %%
#!pip install pandas for windows

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df 
#do not keep space in data as it is a character
# Out:
#    S.N.      Name  Age     Address       Phone
# 0     1       Ram   34   Kathmandu  9861644644
# 1     2     Shyam   56       Patan  9871744744
# 2     3      Hari   45   Bhaktapur  9851544544
# 3     4    Anisha   23        Bara  9851040434
# 4     5   Shivani   36     Chitwan  9841687862
# 5     6    Kushal   17     Pokhara  9801229312

# %%
import pandas as pd 
df = pd.read_csv('data.csv',nrows=6,index_col ='S.N.')
df
# Out:
#           Name   Age     Address       Phone
# S.N.
# 1          Ram    34   Kathmandu  9861644644
# 2        Shyam    56       Patan  9871744744
# 3         Hari    45   Bhaktapur  9851544544
# 4       Anisha    23        Bara  9851040434
# 5      Shivani    36     Chitwan  9841687862
# 6       Kushal    17     Pokhara  9801229312

# %%
#df.head() -> top to bottom
import pandas as pd 
df = pd.read_csv('data.csv',nrows=6,index_col ='S.N.')
df.head()
# Out:
#           Name   Age     Address       Phone
# S.N.
# 1          Ram    34   Kathmandu  9861644644
# 2        Shyam    56       Patan  9871744744
# 3         Hari    45   Bhaktapur  9851544544
# 4       Anisha    23        Bara  9851040434
# 5      Shivani    36     Chitwan  9841687862

# %%
#df.tail() -> bottom to top
import pandas as pd 
df = pd.read_csv('data.csv',nrows=6,index_col ='S.N.')
df.tail()
# Out:
#           Name   Age     Address       Phone
# S.N.
# 2        Shyam    56       Patan  9871744744
# 3         Hari    45   Bhaktapur  9851544544
# 4       Anisha    23        Bara  9851040434
# 5      Shivani    36     Chitwan  9841687862
# 6       Kushal    17     Pokhara  9801229312

# %%
import pandas as pd 
df = pd.read_csv('data.csv',usecols=['S.N.','Name','Phone'],index_col='S.N.')
df.head()
# Out:
#           Name       Phone
# S.N.
# 1          Ram  9861644644
# 2        Shyam  9871744744
# 3         Hari  9851544544
# 4       Anisha  9851040434
# 5      Shivani  9841687862

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')
df.iloc[1:5,0:3]
#[1:5,0:3] -> [row,column]
# Out:
#           Name  Age     Address
# S.N.
# 2        Shyam   56       Patan
# 3         Hari   45   Bhaktapur
# 4       Anisha   23        Bara
# 5      Shivani   36     Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')  #note Index_col = S.N.
df.loc[1:5]
# Out:
#           Name  Age     Address       Phone
# S.N.
# 1          Ram   34   Kathmandu  9861644644
# 2        Shyam   56       Patan  9871744744
# 3         Hari   45   Bhaktapur  9851544544
# 4       Anisha   23        Bara  9851040434
# 5      Shivani   36     Chitwan  9841687862

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='Name') #note Index_col = name
df
# Out:
#           S.N.  Age     Address       Phone
# Name
#  Ram         1   34   Kathmandu  9861644644
#  Shyam       2   56       Patan  9871744744
#  Hari        3   45   Bhaktapur  9851544544
#  Anisha      4   23        Bara  9851040434
#  Shivani     5   36     Chitwan  9841687862
#  Kushal      6   17     Pokhara  9801229312

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='Name') #note Index_col = name
df.loc["Shyam":"Kushal"]
# Out:
#          S.N.  Age    Address       Phone
# Name
# Shyam       2   56      Patan  9871744744
# Hari        3   45  Bhaktapur  9851544544
# Anisha      4   23       Bara  9851040434
# Shivani     5   36    Chitwan  9841687862
# Kushal      6   17    Pokhara  9801229312

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')
df['Address'] == "Kathmandu"
# Out:
# S.N.
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: Address, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')
df[df['Address'] == "Kathmandu"]
# Out:
#      Name  Age    Address       Phone
# S.N.
# 1     Ram   34  Kathmandu  9861644644

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')
df[df['Age'] > 30]
# Out:
#          Name  Age    Address       Phone
# S.N.
# 1         Ram   34  Kathmandu  9861644644
# 2       Shyam   56      Patan  9871744744
# 3        Hari   45  Bhaktapur  9851544544
# 5     Shivani   36    Chitwan  9841687862

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')
df[(df['Age']>30)&(df['Address']=="Kathmandu")]
# Out:
#      Name  Age    Address       Phone
# S.N.
# 1     Ram   34  Kathmandu  9861644644

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='S.N.')
data = df[df['Age']>30]
data.to_csv('new.data.csv')

# %%
#list inside dictionary
import pandas as pd
data = {'name':['Ram','Shyam','Hari'],
        'class':[10,34,56],
        'grade':['A','B','C']}
df = pd.DataFrame(data)
df
# Out:
#     name  class grade
# 0    Ram     10     A
# 1  Shyam     34     B
# 2   Hari     56     C

# %%
import csv
fields = [['Name','Age','Address'],
          ["Kamal",28,"Baluwatar"],
          ["Sabin",23,"Patan"]]

f = open('data.csv','w')
x = csv.writer(f)

for i in fields:
    x.writerow(i)
    
f.close()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#     Name  Age    Address
# 0  Kamal   28  Baluwatar
# 1  Sabin   23      Patan

# %%
import csv 
with open('data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(dict(row))
# Out:
# {'Name': 'Kamal', 'Age': '28', 'Address': 'Baluwatar'}
# {'Name': 'Sabin', 'Age': '23', 'Address': 'Patan'}

# %%
import csv 
csv_data = []
with open('data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        csv_data.append(dict(row))
csv_data
# Out:
# [{'Name': 'Kamal', 'Age': '28', 'Address': 'Baluwatar'},
#  {'Name': 'Sabin', 'Age': '23', 'Address': 'Patan'}]

# %%
import csv
csv_columns = ['Name','Age','Address']
dict = [
    {'Name':'Aayush','Age':23,'Address':'Kathmandu'},
    {'Name':'Shyam','Age':25,'Address':'Patan'}
]

with open("data.csv",'w') as csvfile:
    
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    
    for data in dict:
        writer.writerow(data)

# %%
import pandas as pd 
df = pd.read_csv('data.csv',index_col='Sn')
df.drop([1],axis=0)
# Out:
#      Name  Age    Address
# Sn
# 2   Shyam   25      Patan
# 3   Kamal   54  Bhaktapur

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df.drop(['Kamal'],axis=0)
# Out:
#         Sn  Age    Address
# Name
# Aayush   1   23  Kathmandu
# Shyam    2   25      Patan

# %%
import pandas as pd
df = pd.read_csv('covid.csv')
df
# Out:
#        # Country,Other  TotalCases NewCases TotalDeaths NewDeaths  \
# 0      1           USA  80,532,271  +76,222     972,200    +1,853
# 1      2         India  42,904,744  +10,399     513,512      +254
# 2      3        Brazil  28,671,194  +90,199     648,267      +781
# 3      4        France  22,593,109  +58,138     137,958      +188
# 4      5            UK  18,804,765  +31,933     161,224      +120
# ..   ...           ...         ...      ...         ...       ...
# 221  222          Cook     Islands        9          +1         9
# 222  223      Marshall     Islands        7           7         0
# 223  224         Saint      Helena        2           2         0
# 224  225    Micronesia           1        1           0         9
# 225  226         China     108,604     +224       4,636   101,714
#
#     TotalRecovered       NewRecovered        ActiveCases Serious,Critical  \
# 0       52,863,682           +201,012         26,696,389            8,985
# ...

# %%
import pandas as pd
df = pd.read_csv('covid.csv',index_col = '#')
list(df['Country,Other'])
# Out:
# ['USA',
#  'India',
#  'Brazil',
#  'France',
#  'UK',
#  'Russia',
#  'Germany',
#  'Turkey',
#  'Italy',
#  'Spain',
#  'Argentina',
#  'Iran',
#  'Netherlands',
#  'Colombia',
#  'Poland',
#  'Mexico',
#  'Indonesia',
#  'Ukraine',
#  'Japan',
#  'South',
#  'Philippines',
#  'Israel',
#  'Czechia',
#  'Belgium',
#  'Peru',
#  'Malaysia',
#  'Canada',
#  'Portugal',
#  'Australia',
#  'Vietnam',
#  'Chile',
#  'Thailand',
#  'Switzerland',
#  'Romania',
#  'S.',
#  'Austria',
#  'Denmark',
#  'Sweden',
#  'Greece',
#  'Iraq',
#  'Bangladesh',
#  'Serbia',
#  'Hungary',
#  'Jordan',
#  'Georgia',
#  'Pakistan',
#  'Slovakia',
#  'Kazakhstan',
#  'Ireland',
#  'Norway',
#  'Morocco',
#  'Bulgaria',
#  'Cuba',
#  'Lebanon',
#  'Croatia',
#  'Tunisia',
#  'Nepal',
#  'Belarus',
#  'Bolivia',
#  'Lithuania',
#  'Slovenia',
#  'UAE',
#  'Uruguay',
#  'Ecuador',
#  'Costa',
#  'Azerbaijan',
#  'Guatemala',
#  'Panama',
#  'Saudi',
#  'Singapore',
#  'Sri',
#  'Paraguay',
#  'Finland',
# ...

# %%
import pandas as pd
df = pd.read_csv('covid.csv',index_col = '#')
z = list(df['TotalCases'])
for i in z:
    print(i.replace(",",""))
# Out:
# 80532271
# 42904744
# 28671194
# 22593109
# 18804765
# 16052028
# 14504151
# 13913625
# 12693320
# 10977524
# 8887973
# 7023904
# 6272493
# 6058715
# 5637646
# 5473489
# 5457775
# 4809624
# 4750496
# Africa
# 3658892
# 3607511
# 3559560
# 3537675
# 3506075
# 3367871
# 3277094
# 3241451
# 3151386
# 3120301
# 2985873
# 2819282
# 2753342
# 2717289
# Korea
# 2610286
# 2586038
# 2441142
# 2385304
# 2299767
# 1941057
# 1903494
# 1779174
# 1614698
# 1591936
# 1506450
# 1421546
# 1301253
# 1292212
# 1217306
# 1160562
# 1086328
# 1068148
# 1062879
# 1051697
# 994543
# 976670
# 907978
# 892537
# 891538
# 889202
# 878102
# 835346
# 827760
# Rica
# 782748
# 773575
# 754362
# Arabia
# 679795
# Lanka
# 639813
# 637729
# 633960
# 618121
# 581837
# 574615
# Republic
# 512947
# 506974
# 500144
# 492154
# 483955
# 478984
# 468606
# 463335
# 418792
# 411212
# 379618
# and
# 356066
# 322869
# 315000
# 312374
# Macedonia
# 292126
# 271141
# 264706
# 263950
# 254428
# 236036
# 235467
# 229836
# 225018
# ...
